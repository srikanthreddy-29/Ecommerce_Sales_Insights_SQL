# %% [markdown]
# ## 📊 E-Commerce EDA Analysis and Visualizations
#
# This notebook performs **Exploratory Data Analysis (EDA)** on the cleaned e-commerce datasets to uncover patterns, trends, and insights that drive business decisions.

# %%
# 📦 Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# 📂 Load cleaned datasets
cleaned_path = "../datasets/cleaned_data"

customers = pd.read_csv(os.path.join(cleaned_path, "cleaned_customers.csv"))
geolocation = pd.read_csv(os.path.join(cleaned_path, "cleaned_geolocation.csv"))
order_items = pd.read_csv(os.path.join(cleaned_path, "cleaned_order_items.csv"))
orders = pd.read_csv(os.path.join(cleaned_path, "cleaned_orders.csv"))
payments = pd.read_csv(os.path.join(cleaned_path, "cleaned_payments.csv"))
products = pd.read_csv(os.path.join(cleaned_path, "cleaned_products.csv"))
sellers = pd.read_csv(os.path.join(cleaned_path, "cleaned_sellers.csv"))

# %% [markdown]
# ### 🔍 Basic Info and Null Values Check
# Begin with basic info, descriptive statistics, and null checks on all datasets.

# %%
datasets = {
    "Customers": customers,
    "Order Items": order_items,
    "Orders": orders,
    "Payments": payments,
    "Products": products,
    "Sellers": sellers
}

# %%
for name, df in datasets.items():
    print(f"\n📄 {name} Dataset".upper())

    print("Data Types and Nulls:")
    display(df.info())

    print("\n📊 Descriptive Statistics:")
    display(df.describe(include='all'))

    print("\n🔍 Missing Values:")
    display(df.isnull().sum())
# Out:
# 📄 CUSTOMERS DATASET
# Data Types and Nulls:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# None
# 📊 Descriptive Statistics:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# ...

# %% [markdown]
# ### 📈 1. Top 10 Product Categories

# %%
plt.figure(figsize=(10,6))
top_categories = products['product category'].value_counts().head(10)
sns.barplot(x=top_categories.values, y=top_categories.index,hue=top_categories.index)
plt.title("Top 10 Product Categories")
plt.xlabel("Count")
plt.ylabel("Product Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📉 2. Order Status Distribution

# %%
plt.figure(figsize=(8,6))
order_status_counts = orders['order_status'].value_counts()
sns.countplot(data=orders, y='order_status', order=order_status_counts.index)
plt.title("Order Status Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 💳 3. Payment Type Pie Chart

# %%
plt.figure(figsize=(7,8))
payment_types = payments['payment_type'].value_counts()
plt.pie(payment_types.values, labels=payment_types.index, autopct='%1.1f%%', startangle=140)
plt.title("Payment Type Distribution")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🚚 4. Freight vs Price (Scatter)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=order_items, x='price', y='freight_value')
plt.title("Freight vs. Product Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ⚖️ 5. Distribution of Product Weights

# %%
plt.figure(figsize=(10,6))
sns.histplot(products['product_weight_g'], bins=30, kde=True)
plt.title("Distribution of Product Weights")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📉 6. lmplot: Freight vs Price by Category

# %%
top3 = top5_products['product category'].value_counts().head(3).index.tolist()
filtered = merged[merged['product category'].isin(top3)]

sns.lmplot(data=filtered, x='price', y='freight_value', hue='product category', fit_reg=False, height=6, aspect=1.4)
plt.title("Freight vs Price by Product Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📈 7. Line Plot – Monthly Order Trends

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
monthly_orders = orders.groupby(orders['order_purchase_timestamp'].dt.to_period('M')).size()

plt.figure(figsize=(9,6))
monthly_orders.plot(kind='line', marker='o')
plt.title("Monthly Order Volume")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🧭 8. Count Plot – Customers per State

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=customers, x="customer_state", order=customers["customer_state"].value_counts().index,hue="customer_state")
plt.title("Number of Customers per State")
plt.xlabel("State")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
